# %% [markdown]
# # **Text Generation With GPT-2 Model**

# %%
# Install the required library
# !pip install transformers

# Import the necessary library
from transformers import pipeline

# Load the text generation pipeline with GPT-2
generator = pipeline('text-generation', model='gpt2')

# Define your prompt
prompt = "The future of AI is"

# Generate text based on the prompt
results = generator(prompt, max_length=500, num_return_sequences=1)

# Print the generated text
print("Generated text:", results[0]['generated_text'])
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %%
prompt = "The history of the world is"

# Generate text based on the prompt
results = generator(prompt, max_length=500, num_return_sequences=1)

# Print the generated text
print("Generated text:", results[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated text: The history of the world is littered with many people trying to gain a sense of peace with their fellow citizens. In many cases it was this desire to unite and share this world that made this great and great land become the home of the future. The reason that this nation is so important to all of humankind is that it's home to the most noble and important people from the world." That's probably right. This is why he's so proud that the King of the Great Plains, Jolyne, joined him.
#
# Saying that for as long as he has, I know he'd never have met Jolyne and I would be proud of this person in a lot of ways but, it would need to have been quite a bit of work to get them all on this team together. It would have been a bit of a hard task to get him all on our team but, he'd come to our team pretty easy. He'd never have done it such a way but, that wasn't hard.
#
# ...
